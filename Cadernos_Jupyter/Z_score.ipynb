# %%
# Revisão e Z-Scores
#
# Teorema central do limite
#
# Z-Scores

# %%
import numpy as np
import random
import seaborn as sns

# %%
x = [21,18,19,19,19,18,19,19,18,21,18,18,18,17,18,18,26,21,21,19,19,18,18,19,20,18,20,18,34]

desvio_padrao = 0
media = np.mean(x)
for i in x:
    desvio_padrao = desvio_padrao + (i - media)**2
desvio_padrao = (desvio_padrao / len(x))**0.5
desvio_padrao_np = np.std(x)
desvio_padrao, desvio_padrao_np, media
# Out:
# (3.1992864840670907, 3.1992864840670907, 19.620689655172413)

# %%
sns.distplot(x)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8364\3746914587.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x)
# <Axes: ylabel='Density'>

# %%
def zscore(x):
    media = np.mean(x)
    desvio = np.std(x)
    z = []
    for i in x:
        z.append((i - media) / desvio)
    return z

z = zscore(x)
z
# Out:
# [0.4311306135592271,
#  -0.5065784709320912,
#  -0.19400877610165174,
#  -0.19400877610165174,
#  -0.19400877610165174,
#  -0.5065784709320912,
#  -0.19400877610165174,
#  -0.19400877610165174,
#  -0.5065784709320912,
#  0.4311306135592271,
#  -0.5065784709320912,
#  -0.5065784709320912,
#  -0.5065784709320912,
#  -0.8191481657625306,
#  -0.5065784709320912,
#  -0.5065784709320912,
#  1.993979087711424,
#  0.4311306135592271,
#  0.4311306135592271,
#  -0.19400877610165174,
#  -0.19400877610165174,
#  -0.5065784709320912,
#  -0.5065784709320912,
#  -0.19400877610165174,
#  0.11856091872878767,
#  -0.5065784709320912,
#  0.11856091872878767,
#  -0.5065784709320912,
#  4.494536646354939]

# %%
sns.distplot(z)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8364\2629282914.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z)
# <Axes: ylabel='Density'>

# %%
# Teorema central do limite
# Dada uma população que possui uma distribuição de probabilidade qualquer, a média de amostras dessa distribuição terá distribuição normal.

# %%
n = 1000
n_amostras = 10
medias = []
for i in range(n):
    escolhidos = np.random.choice(x, size = n_amostras, replace = False)
    media = np.mean(escolhidos)
    medias.append(media)
sns.distplot(medias)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8364\3865769241.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(medias)
# <Axes: ylabel='Density'>

# %%
n = 1000
n_amostras = 10
medias = []
for i in range(n):
  escolhidos = np.random.choice(z,size = n_amostras, replace = False)
  media = np.mean(escolhidos)
  medias.append(media)
sns.distplot(medias)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8364\1721686325.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(medias)
# <Axes: ylabel='Density'>

# %%
y = []
for i in range(n):
  y.append(random.randint(17,26))
sns.distplot(y)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8364\1289085675.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y)
# <Axes: ylabel='Density'>

# %%
n = 1000
n_amostras = 10
medias = []
for i in range(n):
  escolhidos = np.random.choice(y,size = n_amostras, replace = False)
  media = np.mean(escolhidos)
  medias.append(media)
sns.distplot(medias)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8364\4293923506.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(medias)
# <Axes: ylabel='Density'>
