# %%
eventos_dado = [1, 2, 3, 4, 5, 6]

# %%
eventos_dado[0]
# Out:
# 1

# %%
eventos_dado[1]
# Out:
# 2

# %%
#controle de fluxo
for evento in eventos_dado:
  print(evento)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
#Probabilidade Condicional com a Fórmula de Bayes
p_a = 0.1
p_b_dado_a = 0.75
p_b = 0.75 * 0.1 + 0.25 * 0.9
p_a_dado_b = p_b_dado_a * p_a/p_b
print(f"A probabilidade de se estar com gripe (a), dado que se está com tosse é {p_a_dado_b}.")
# Out:
# A probabilidade de se estar com gripe (a), dado que se está com tosse é 0.25.

# %%
from matplotlib import pyplot as plt
from random import randint, choice

resultados = [0, 0, 0, 0, 0, 0]
resultados
# Out:
# [0, 0, 0, 0, 0, 0]

# %%
for i in range(10000000):
  resultado = randint(1, 6)
  resultados[resultado - 1] += 1
resultados
# Out:
# [1683192, 1683473, 1684592, 1682056, 1683692, 1683995]
