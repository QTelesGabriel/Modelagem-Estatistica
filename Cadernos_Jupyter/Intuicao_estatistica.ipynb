# %%
"""Atividade Prática 2 - Intuição.ipynb

Automatically generated by Colaboratory.

Original file is located at
    http://localhost:8888/notebooks/Modelagem%20e%20programação%20estatística/Trabalhos/Distribuições%20de%20Probabilidade%20e%20o%20Teorema%20Central%20de%20Limite.ipynb
"""
# Out:
# 'Atividade Prática 2 - Intuição.ipynb\n\nAutomatically generated by Colaboratory.\n\nOriginal file is located at\n    http://localhost:8888/notebooks/Modelagem%20e%20programação%20estatística/Trabalhos/Distribuições%20de%20Probabilidade%20e%20o%20Teorema%20Central%20de%20Limite.ipynb\n'

# %%
import numpy as np
import random
import seaborn as sns

# %%
tamanho = 10000
x = []
for i in range(10000):
    resultado = np.random.randint(1, 6)
    x.append(resultado)
len(x)
# Out:
# 10000

# %%
desvio_padrao = 0
media = np.mean(x)
for i in x:
    desvio_padrao = desvio_padrao + (i-media)**2
desvio_padrao = (desvio_padrao / len(x))**0.5
desvio_padrao
# Out:
# 1.4272617139124488

# %%
desvio_padrao_np = np.std(x)
desvio_padrao, desvio_padrao_np, media
# Out:
# (1.4272617139124488, 1.4272617139123436, 2.982)

# %%
x = [21,18,19,19,19,18,19,19,18,21,18,18,18,17,18,18,26,21,21,19,19,18,18,19,20,18,20,18]

desvio_padrao = 0
media = np.mean(x)
for i in x:
    desvio_padrao = desvio_padrao + (i-media)**2
desvio_padrao = (desvio_padrao / len(x))**0.5
desvio_padrao_np = np.std(x)

desvio_padrao, desvio_padrao_np, media
# Out:
# (1.718373103388487, 1.718373103388487, 19.107142857142858)

# %%
# Dado viciado
tamanho = 10000
x = []
for i in range(10000):
    if i % 3 == 0:
        resultado = np.random.choice([5, 6])
    else:
        resultado = np.random.randint(1, 6)
    x.append(resultado)

len(x)
desvio_padrao = 0
media = np.mean(x)
for i in x:
    desvio_padrao = desvio_padrao + (i-media)**2
desvio_padrao = (desvio_padrao / len(x))**0.5
desvio_padrao_np = np.std(x)
desvio_padrao, desvio_padrao_np, media

sns.distplot(x)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_3356\485340719.py:20: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x)
# <Axes: ylabel='Density'>
